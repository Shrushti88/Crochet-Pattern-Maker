# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrushti88/Crochet-Pattern-Maker/blob/main/Prelab_CM23006.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import cv2
import tensorflow as tf

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-Learn:", sklearn.__version__)
print("OpenCV:", cv2.__version__)
print("TensorFlow:", tf.__version__)
# Out:
# NumPy: 2.0.2
# Pandas: 2.2.2
# Scikit-Learn: 1.6.1
# OpenCV: 4.13.0
# TensorFlow: 2.20.0

# %%
from sklearn.datasets import load_iris

iris = load_iris()

print("Feature Names:", iris.feature_names)
print("Target Names:", iris.target_names)
print("Number of Samples:", len(iris.data))
# Out:
# Feature Names: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Target Names: ['setosa' 'versicolor' 'virginica']
# Number of Samples: 150

# %%
import pandas as pd

df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target

print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
# None
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(df['sepal length (cm)'])
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.title("Sepal Length Distribution")
plt.show()

# %%
plt.scatter(df['sepal length (cm)'], df['petal length (cm)'])
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Sepal Length vs Petal Length")
plt.show()

# %%
# !git clone https://github.com/Shrushti88/Pattern-Recognition
# %cd repository

# Copy your notebook into the repository folder if needed

# !git add .
# !git commit -m "Add notebook"
# !git push origin main
# Out:
# fatal: destination path 'Pattern-Recognition' already exists and is not an empty directory.
# [Errno 2] No such file or directory: 'repository'
# /content
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git add .
# !git commit -m "Add Pattern Recognition notebook"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
